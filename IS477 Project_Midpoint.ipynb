# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Base project folder
project_folder = '/content/drive/MyDrive/IS477_PlayerSalaries_Project/'

# Data folder
data_folder = project_folder + 'Data/'


player_salaries_csv_file = data_folder + 'NBA Player Stats and Salaries_2000-2025.csv'

seasons_csv_file = data_folder + 'Season Data(Sheet1).csv'

salaries_df = pd.read_csv(player_salaries_csv_file)

seasons_df = pd.read_csv(seasons_csv_file)

# %% [markdown]
# **Salary Data Processing**

# %%
salaries_df = pd.read_csv(player_salaries_csv_file)
salaries_df.head()
# Out:
#              Player    Salary  Year Pos  Age Team   G  GS    MP    FG  ...  \
# 0  Shaquille O'Neal  17142000  2000   C   27  LAL  79  79  40.0  12.1  ...
# 1     Kevin Garnett  16806000  2000  PF   23  MIN  81  81  40.0   9.4  ...
# 2   Alonzo Mourning  15004000  2000   C   29  MIA  79  78  34.8   8.3  ...
# 3      Juwan Howard  15000000  2000  PF   26  WAS  82  82  35.5   6.2  ...
# 4    Scottie Pippen  14795000  2000  SF   34  POR  82  82  33.5   4.7  ...
#
#      FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  0.524  4.3  9.4  13.6  3.8  0.5  3.0  2.8  3.2  29.7
# 1  0.765  2.8  9.0  11.8  5.0  1.5  1.6  3.3  2.5  22.9
# 2  0.711  2.7  6.8   9.5  1.6  0.5  3.7  2.7  3.9  21.7
# 3  0.735  1.6  4.1   5.7  3.0  0.8  0.3  2.7  3.6  14.9
# 4  0.717  1.4  4.9   6.3  5.0  1.4  0.5  2.5  2.5  12.5
#
# [5 rows x 31 columns]

# %%
#Including only relevant columns in the datafram
contracts_relevant_columns = ["Player", "Salary", "Pos", "Year", "Team"]
salaries_df = salaries_df[contracts_relevant_columns]
salaries_df.head()
# Out:
#              Player    Salary Pos  Year Team
# 0  Shaquille O'Neal  17142000   C  2000  LAL
# 1     Kevin Garnett  16806000  PF  2000  MIN
# 2   Alonzo Mourning  15004000   C  2000  MIA
# 3      Juwan Howard  15000000  PF  2000  WAS
# 4    Scottie Pippen  14795000  SF  2000  POR

# %%
#Looking at null values
salaries_df.isnull().sum()
# Out:
# Player    0
# Salary    0
# Pos       0
# Year      0
# Team      0
# dtype: int64

# %%
#Looking at all of the values for Year
salaries_df['Year'].value_counts()
# Out:
# Year
# 2022    540
# 2024    493
# 2025    489
# 2021    485
# 2023    467
# 2017    465
# 2015    465
# 2012    454
# 2019    449
# 2016    446
# 2013    438
# 2011    435
# 2020    435
# 2009    427
# 2008    424
# 2010    424
# 2007    422
# 2006    420
# 2014    411
# 2002    402
# 2018    402
# 2001    361
# 2003    272
# 2004    177
# 2000    153
# 2005    117
# Name: count, dtype: int64

# %%
#Looking all of the values for Team
salaries_df['Team'].value_counts()
# Out:
# Team
# PHI    369
# MIL    365
# CLE    360
# SAS    360
# NYK    359
# TOR    358
# ATL    357
# IND    357
# SAC    356
# MIA    356
# DAL    356
# POR    355
# UTA    352
# GSW    351
# LAL    350
# MEM    349
# WAS    348
# LAC    347
# DET    346
# BOS    346
# MIN    345
# PHO    345
# HOU    339
# CHI    326
# DEN    322
# ORL    320
# OKC    271
# BRK    204
# NOP    183
# CHO    159
# NJN    157
# CHA    129
# NOH    110
# SEA     87
# CHH     32
# NOK     28
# VAN     19
# Name: count, dtype: int64

# %%
#Looking at all of the values for Position
salaries_df['Pos'].value_counts()
# Out:
# Pos
# SG       2218
# C        2112
# PF       2098
# PG       1943
# SF       1909
# PG-SG      29
# SF-SG      28
# C-PF       24
# SG-PG      24
# SG-SF      22
# PF-SF      22
# PF-C       21
# SF-PF      17
# SG-PF       4
# PG-SF       1
# SF-C        1
# Name: count, dtype: int64

# %%
#Looking at some examples of SF-SG
salaries_df[salaries_df['Pos']=='SF-SG']
# Out:
#                  Player    Salary    Pos  Year Team
# 295        Tyrone Nesby   2990000  SF-SG  2001  WAS
# 1387       Vince Carter  13281000  SF-SG  2005  NJN
# 1401   Shandon Anderson   7300000  SF-SG  2005  MIA
# 1493         Jalen Rose  15694250  SF-SG  2006  NYK
# 1573    Ruben Patterson   6353200  SF-SG  2006  DEN
# 1996    Stephen Jackson   6120000  SF-SG  2007  GSW
# 2724  Jeremy Richardson    238588  SF-SG  2008  ATL
# 2782       Larry Hughes  12827676  SF-SG  2009  NYK
# 3000    Thabo Sefolosha   1931160  SF-SG  2009  OKC
# 3235       Caron Butler   9780970  SF-SG  2010  DAL
# 3481       Quinton Ross   1033342  SF-SG  2010  WAS
# 3597          Coby Karl     17328  SF-SG  2010  GSW
# 3766       Corey Brewer   3875000  SF-SG  2011  DAL
# 5527   Quincy Pondexter   3146068  SF-SG  2015  NOP
# 6850       Corey Brewer   7579366  SF-SG  2018  OKC
# 7155       Jimmy Butler  20445779  SF-SG  2019  PHI
# 7531    Wesley Matthews    512746  SF-SG  2019  IND
# 7858    James Ennis III   1882867  SF-SG  2020  ORL
# 7883         Alec Burks   1620564  SF-SG  2020  PHI
# 8063      Evan Fournier  20900558  SF-SG  2021  BOS
# 8348      Javonte Green   1849950  SF-SG  2021  CHI
# 8562      Norman Powell  17943324  SF-SG  2022  LAC
# 8589        Jeremy Lamb  12141649  SF-SG  2022  SAC
# 8644     Justin Holiday   6945508  SF-SG  2022  SAC
# 8766        Rodney Hood   2589691  SF-SG  2022  LAC
# 8936       Malcolm Hill    375086  SF-SG  2022  CHI
# 9122          Josh Hart  13741332  SF-SG  2023  NYK
# 9563        Buddy Hield  19895988  SF-SG  2024  PHI

# %%
#Changing some of the positions so that only the main 5 remain
salaries_df['Pos'] = salaries_df['Pos'].str.split('-').str[0]

# %%
salaries_df['Pos'].unique()
# Out:
# array(['C', 'PF', 'SF', 'PG', 'SG'], dtype=object)

# %%
#Grouping by Team, Year, and Position to get the salary spent on each position
grouped = salaries_df.groupby(['Team', 'Year', 'Pos'])['Salary'].sum().reset_index()
grouped.head()
# Out:
#   Team  Year Pos   Salary
# 0  ATL  2000   C  4400000
# 1  ATL  2000  PF  7318000
# 2  ATL  2000  PG  1468000
# 3  ATL  2000  SF  1939000
# 4  ATL  2000  SG   893000

# %%
#Getting the total money spend by each team for every season
team_totals = salaries_df.groupby(['Team', 'Year'])['Salary'].sum().reset_index()
team_totals = team_totals.rename(columns={'Salary': 'TeamTotal'})
team_totals.sample(n=10)
# Out:
#     Team  Year  TeamTotal
# 511  NYK  2024  154710344
# 183  DEN  2016   47658813
# 728  UTA  2007   60325348
# 328  LAL  2005   31756000
# 765  WAS  2016   67194598
# 164  DAL  2023  152640713
# 338  LAL  2015   61382322
# 155  DAL  2014   67279965
# 381  MIA  2008   68207076
# 490  NYK  2003   59885000

# %%
#Merging the team totals and grouped dfs to get the percent spend on each position each year
merged = grouped.merge(team_totals, on=['Team','Year'])
merged['Percent'] = merged['Salary'] / merged['TeamTotal'] * 100
merged
# Out:
#      Team  Year Pos    Salary  TeamTotal    Percent
# 0     ATL  2000   C   4400000   16018000  27.469097
# 1     ATL  2000  PF   7318000   16018000  45.686103
# 2     ATL  2000  PG   1468000   16018000   9.164690
# 3     ATL  2000  SF   1939000   16018000  12.105132
# 4     ATL  2000  SG    893000   16018000   5.574978
# ...   ...   ...  ..       ...        ...        ...
# 3726  WAS  2025   C  11245680  166294208   6.762521
# 3727  WAS  2025  PF  14886012  166294208   8.951612
# 3728  WAS  2025  PG  47165164  166294208  28.362482
# 3729  WAS  2025  SF  50312899  166294208  30.255353
# 3730  WAS  2025  SG  42684453  166294208  25.668033
#
# [3731 rows x 6 columns]

# %%
league_spending = (
    merged
    .groupby(['Year', 'Pos'])['Salary']
    .sum()
    .unstack(fill_value=0)
    .sort_index()
)

league_spending_pct = league_spending.div(league_spending.sum(axis=1), axis=0)

plt.figure(figsize=(12, 7))

league_spending_pct.plot(
    kind='bar',
    stacked=True,
    figsize=(12, 7)
)

plt.xlabel('Year')
plt.ylabel('Share of Spending (%)')
plt.title('Leaguewide Spending Distribution by Position (Normalized)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Season Data Processing**

# %%
seasons_df = seasons_df.iloc[:, :21]
# Only includes regular season stats and playoff W/L Totals

# %%
seasons_df = seasons_df[seasons_df['Year'] > 2004]
# Filter to only include 2005 and beyond

# %%
seasons_df[['PostW', 'PostL']] = seasons_df[['PostW', 'PostL']].fillna(0)
# Fills empty playoff W/L total columns with zero, as these were intentionally left blank since team missed playoffs

# %%
seasons_df['Playoffs'] = (seasons_df[['PostW', 'PostL']].sum(axis=1) > 0).astype(int)
# Creates 0/1 Boolean for whether team made playoffs or not

# %%
seasons_df['Championship'] = (
    seasons_df['Team'].str.contains(r'\?', regex=True)
).astype(int)
# Creates 0/1 Boolean for championship teams, teams that won championship had emoji in team name that was read as question marks

# %%
seasons_df['Team'] = seasons_df['Team'].str.replace('?', '', regex=False)
# Drops aforementioned question marks after championship files created

# %%
seasons_df = seasons_df[seasons_df['Team'].isin(seasons_df['Team'].value_counts()[seasons_df['Team'].value_counts() >= 17].index)]
# Filter for teams that have 17 or more appearances in last 20 years (teams in NBA have shifted over the years)

# %%
seasons_df.isna().sum()
# Succesful check for na values
# Out:
# Season_ID       0
# Team            0
# Year            0
# TR              0
# Age             0
# W               0
# L               0
# SRS             0
# ORtg            0
# rORtg           0
# DRtg            0
# rDRtg           0
# NRtg            0
# Pace            0
# rPace           0
# FTr             0
# rFTr            0
# TS              0
# rTS             0
# PostW           0
# PostL           0
# Playoffs        0
# Championship    0
# dtype: int64

# %%
team_map = {
    'Oklahoma City Thunder': 'OKC',
    'Cleveland Cavaliers': 'CLE',
    'Boston Celtics': 'BOS',
    'Minnesota Timberwolves': 'MIN',
    'Indiana Pacers': 'IND',
    'New York Knicks': 'NYK',
    'Denver Nuggets': 'DEN',
    'Los Angeles Clippers': 'LAC',
    'Houston Rockets': 'HOU',
    'Golden State Warriors': 'GSW',
    'Memphis Grizzlies': 'MEM',
    'Detroit Pistons': 'DET',
    'Sacramento Kings': 'SAC',
    'Los Angeles Lakers': 'LAL',
    'Milwaukee Bucks': 'MIL',
    'Dallas Mavericks': 'DAL',
    'Atlanta Hawks': 'ATL',
    'Chicago Bulls': 'CHI',
    'Orlando Magic': 'ORL',
    'San Antonio Spurs': 'SAS',
    'Phoenix Suns': 'PHO',
    'Portland Trail Blazers': 'POR',
    'Toronto Raptors': 'TOR',
    'Miami Heat': 'MIA',
    'Philadelphia 76ers': 'PHI',
    'Utah Jazz': 'UTA',
    'Washington Wizards': 'WAS'
}
# Creates map to match abbreviate salary team names to full names in season results dataset

# %%
seasons_df
# Out:
#      Season_ID                    Team    Year    TR   Age     W     L   SRS  \
# 0          1.0   Oklahoma City Thunder  2025.0  15.6  24.8  68.0  14.0  12.7
# 1          2.0     Cleveland Cavaliers  2025.0  11.2  26.6  64.0  18.0   8.8
# 2          3.0          Boston Celtics  2025.0  10.2  28.9  61.0  21.0   8.3
# 3          4.0  Minnesota Timberwolves  2025.0   9.3  27.2  49.0  33.0   5.2
# 4          5.0          Indiana Pacers  2025.0   8.5  25.8  50.0  32.0   1.7
# ..         ...                     ...     ...   ...   ...   ...   ...   ...
# 572      623.0         New York Knicks  2005.0  -3.0  27.3  33.0  49.0  -2.7
# 573      624.0         Milwaukee Bucks  2005.0  -3.5  26.9  30.0  52.0  -3.1
# 575      626.0  Portland Trail Blazers  2005.0  -4.0  27.0  27.0  55.0  -3.5
# 576      627.0               Utah Jazz  2005.0  -4.3  25.7  26.0  56.0  -3.7
# 579      630.0           Atlanta Hawks  2005.0 -10.8  26.0  13.0  69.0  -9.6
#
#       ORtg  rORtg  ...   Pace  rPace    FTr   rFTr     TS    rTS  PostW  \
# 0    120.3    5.8  ...  100.0    1.2  0.220 -0.023  0.593  0.017   16.0
# 1    121.7    7.2  ...   99.8    1.0  0.241 -0.002  0.607  0.031    5.0
# 2    120.6    6.1  ...   95.7   -3.1  0.212 -0.031  0.591  0.015    6.0
# 3    116.6    2.1  ...   97.3   -1.5  0.249  0.006  0.588  0.012    9.0
# 4    116.5    2.0  ...   99.9    1.1  0.241 -0.002  0.594  0.018   15.0
# ..     ...    ...  ...    ...    ...    ...    ...    ...    ...    ...
# 572  106.2    0.1  ...   90.7   -0.2  0.312 -0.012  0.531  0.002    0.0
# 573  106.6    0.5  ...   90.8   -0.1  0.339  0.015  0.527 -0.002    0.0
# 575  103.2   -2.9  ...   89.8   -1.1  0.303 -0.021  0.524 -0.005    0.0
# 576  104.7   -1.4  ...   88.4   -2.5  0.361  0.037  0.522 -0.007    0.0
# 579  100.6   -5.5  ...   91.4    0.5  0.299 -0.025  0.504 -0.025    0.0
#
#      PostL  Playoffs  Championship
# 0      7.0         1             1
# 1      4.0         1             0
# 2      5.0         1             0
# 3      6.0         1             0
# 4      8.0         1             0
# ..     ...       ...           ...
# 572    0.0         0             0
# 573    0.0         0             0
# 575    0.0         0             0
# 576    0.0         0             0
# 579    0.0         0             0
#
# [519 rows x 23 columns]

# %%
seasons_df['Team'].unique()
# Out:
# array(['Oklahoma City Thunder', 'Cleveland Cavaliers', 'Boston Celtics',
#        'Minnesota Timberwolves', 'Indiana Pacers', 'New York Knicks',
#        'Denver Nuggets', 'Los Angeles Clippers', 'Houston Rockets',
#        'Golden State Warriors', 'Memphis Grizzlies', 'Detroit Pistons',
#        'Sacramento Kings', 'Los Angeles Lakers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Atlanta Hawks', 'Chicago Bulls',
#        'Orlando Magic', 'San Antonio Spurs', 'Phoenix Suns',
#        'Portland Trail Blazers', 'Toronto Raptors', 'Miami Heat',
#        'Philadelphia 76ers', 'Utah Jazz', 'Washington Wizards'],
#       dtype=object)

# %%
# Create championship distribution pie chart
champions_df = seasons_df[seasons_df['Championship'] == 1]
counts = champions_df.Team.value_counts()
plt.figure(figsize=(8, 8))
plt.pie(
    counts,
    labels=counts.index,
    autopct='%1.1f%%',
    startangle=90
)

plt.title('Distribution of Championship Winning Teams')
plt.tight_layout()
plt.show()

# %%
avg_wins = seasons_df.groupby(['Year', 'Playoffs'])['W'].mean().unstack()

plt.figure(figsize=(12, 6))
avg_wins.plot(kind='bar', figsize=(12, 6))

plt.xlabel('Season')
plt.ylabel('Average Wins')
plt.title('Average Wins by Playoff Status Each Season')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
# Creates winning percentage average across dataset for each team
seasons_df['win_pct'] = seasons_df['W'] / (seasons_df['W'] + seasons_df['L'])
avg_win_pct_by_team = (
    seasons_df
    .groupby('Team')['win_pct']
    .mean()
    .sort_values(ascending=False)
)



plt.figure(figsize=(12, 6))
avg_win_pct_by_team.plot(kind='bar')

plt.xlabel('Team')
plt.ylabel('Average Win Percentage')
plt.title('Average Win Percentage by Team Across All Seasons')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# Merged DataFrame

# %%
#Creating Pivot Table to have df with the percent spend on each position for each team each year
pivoted = merged.pivot_table(
    index=['Team', 'Year'],
    columns='Pos',
    values='Percent',
    fill_value=0
).reset_index()
pivoted = pivoted.rename(columns=lambda x: f"Percent_{x}" if x not in ['Team','Year'] else x)
pivoted
# Out:
# Pos Team  Year  Percent_C  Percent_PF  Percent_PG  Percent_SF  Percent_SG
# 0    ATL  2000  27.469097   45.686103    9.164690   12.105132    5.574978
# 1    ATL  2001  17.846723   25.595257   15.051605   33.541425    7.964990
# 2    ATL  2002  26.954274   43.473161    2.594433   21.578529    5.399602
# 3    ATL  2003  43.634683   26.376827    8.594050   17.195075    4.199365
# 4    ATL  2004  26.629288   28.519557    7.830730    0.000000   37.020425
# ..   ...   ...        ...         ...         ...         ...         ...
# 770  WAS  2021  16.234206   17.965722   35.502832    3.337563   26.959677
# 771  WAS  2022   8.272764   41.420870    2.803299    2.665284   44.837782
# 772  WAS  2023   4.850377   16.206851   18.326630    8.387168   52.228974
# 773  WAS  2024  12.062529   22.977728   11.669991   15.265745   38.024007
# 774  WAS  2025   6.762521    8.951612   28.362482   30.255353   25.668033
#
# [775 rows x 7 columns]

# %%
#Making sure both dfs have the same type so they are ready to merge
seasons_df['Year'] = seasons_df['Year'].astype(int)
pivoted['Year'] = pivoted['Year'].astype(int)
seasons_df['Team'] = seasons_df['Team'].astype(str)
pivoted['Team'] = pivoted['Team'].astype(str)

# %%
#Creating column for team abbreviation
seasons_df['TeamAbbr'] = seasons_df['Team'].map(team_map)

# %%
#Merged pivot and seasons df to create a df with each teams performance and spending for every season
full_df = seasons_df.merge(
    pivoted,
    left_on=['TeamAbbr','Year'],
    right_on=['Team','Year'],
    how='left'
)

# %%
full_df = full_df.drop(columns=['Team_y'])
full_df = full_df.rename(columns={'Team_x':'Team'})

# %%
full_df.columns
# Out:
# Index(['Season_ID', 'Team', 'Year', 'TR', 'Age', 'W', 'L', 'SRS', 'ORtg',
#        'rORtg', 'DRtg', 'rDRtg', 'NRtg', 'Pace', 'rPace', 'FTr', 'rFTr', 'TS',
#        'rTS', 'PostW', 'PostL', 'Playoffs', 'Championship', 'win_pct',
#        'TeamAbbr', 'Percent_C', 'Percent_PF', 'Percent_PG', 'Percent_SF',
#        'Percent_SG'],
#       dtype='object')

# %%
full_df.head()
# Out:
#    Season_ID                    Team  Year    TR   Age     W     L   SRS  \
# 0        1.0   Oklahoma City Thunder  2025  15.6  24.8  68.0  14.0  12.7
# 1        2.0     Cleveland Cavaliers  2025  11.2  26.6  64.0  18.0   8.8
# 2        3.0          Boston Celtics  2025  10.2  28.9  61.0  21.0   8.3
# 3        4.0  Minnesota Timberwolves  2025   9.3  27.2  49.0  33.0   5.2
# 4        5.0          Indiana Pacers  2025   8.5  25.8  50.0  32.0   1.7
#
#     ORtg  rORtg  ...  PostL  Playoffs  Championship   win_pct  TeamAbbr  \
# 0  120.3    5.8  ...    7.0         1             1  0.829268       OKC
# 1  121.7    7.2  ...    4.0         1             0  0.780488       CLE
# 2  120.6    6.1  ...    5.0         1             0  0.743902       BOS
# 3  116.6    2.1  ...    6.0         1             0  0.597561       MIN
# 4  116.5    2.0  ...    8.0         1             0  0.609756       IND
#
#    Percent_C  Percent_PF  Percent_PG  Percent_SF  Percent_SG
# 0  29.570211    5.536712   22.851085   12.265886   29.776106
# 1  12.886080   10.394333   22.529853   21.532788   32.656945
# 2  23.067045   19.792951   18.710290   26.927949   11.501765
# 3  29.312903   27.413927   10.027597    2.931981   30.313593
# 4  17.374625   37.574494   30.411256   10.779217    3.860409
#
# [5 rows x 30 columns]

# %%
full_df.isna().sum()
# Out:
# Season_ID       0
# Team            0
# Year            0
# TR              0
# Age             0
# W               0
# L               0
# SRS             0
# ORtg            0
# rORtg           0
# DRtg            0
# rDRtg           0
# NRtg            0
# Pace            0
# rPace           0
# FTr             0
# rFTr            0
# TS              0
# rTS             0
# PostW           0
# PostL           0
# Playoffs        0
# Championship    0
# win_pct         0
# TeamAbbr        0
# Percent_C       0
# Percent_PF      0
# Percent_PG      0
# Percent_SF      0
# Percent_SG      0
# dtype: int64

# %%
#Defining position columns
position_cols = ['Percent_PG', 'Percent_C', 'Percent_SF', 'Percent_SG', 'Percent_PF']

# %%
print(full_df[position_cols].describe())
# Out:
#        Percent_PG   Percent_C  Percent_SF  Percent_SG  Percent_PF
# count  519.000000  519.000000  519.000000  519.000000  519.000000
# mean    18.990597   22.097083   17.556339   19.813934   21.542047
# std     10.704712   12.367635   12.100165   11.815828   12.759355
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     11.422866   13.898797    8.529958   10.865972   12.924753
# 50%     18.734246   21.814867   15.997378   18.523243   20.165415
# 75%     25.459351   29.688009   24.483944   26.263471   28.803247
# max     79.222070  100.000000   77.812161  100.000000  100.000000

# %%
zero_min_cols = [col for col in position_cols if full_df[col].min() == 0]
for col in zero_min_cols:
    print(f"\nRows with 0 in {col}:")
    print(full_df[full_df[col] == 0][['Team','Year',col]])
# Out:
# Rows with 0 in Percent_PG:
#                        Team  Year  Percent_PG
# 106         Houston Rockets  2022         0.0
# 495         Detroit Pistons  2005         0.0
# 497        Dallas Mavericks  2005         0.0
# 499  Minnesota Timberwolves  2005         0.0
# 500        Sacramento Kings  2005         0.0
# 501          Denver Nuggets  2005         0.0
# 503          Boston Celtics  2005         0.0
# 504     Cleveland Cavaliers  2005         0.0
# 505       Memphis Grizzlies  2005         0.0
# 506           Chicago Bulls  2005         0.0
# 507      Washington Wizards  2005         0.0
# 508    Los Angeles Clippers  2005         0.0
# 510         Toronto Raptors  2005         0.0
# 511      Los Angeles Lakers  2005         0.0
# 513           Orlando Magic  2005         0.0
# 515         Milwaukee Bucks  2005         0.0
# 518           Atlanta Hawks  2005         0.0
#
# Rows with 0 in Percent_C:
#                       Team  Year  Percent_C
# 493           Phoenix Suns  2005        0.0
# 500       Sacramento Kings  2005        0.0
# 503         Boston Celtics  2005        0.0
# 506          Chicago Bulls  2005        0.0
# 508   Los Angeles Clippers  2005        0.0
# 509  Golden State Warriors  2005        0.0
# 514        New York Knicks  2005        0.0
# 517              Utah Jazz  2005        0.0
#
# Rows with 0 in Percent_SF:
#                      Team  Year  Percent_SF
# 10      Memphis Grizzlies  2025         0.0
# 92         Denver Nuggets  2022         0.0
# 135    Los Angeles Lakers  2020         0.0
# 236      Dallas Mavericks  2017         0.0
# 313       New York Knicks  2014         0.0
# 495       Detroit Pistons  2005         0.0
# 501        Denver Nuggets  2005         0.0
# 502        Indiana Pacers  2005         0.0
# 503        Boston Celtics  2005         0.0
# 504   Cleveland Cavaliers  2005         0.0
# 506         Chicago Bulls  2005         0.0
# 507    Washington Wizards  2005         0.0
# 508  Los Angeles Clippers  2005         0.0
# 511    Los Angeles Lakers  2005         0.0
# 517             Utah Jazz  2005         0.0
# 518         Atlanta Hawks  2005         0.0
#
# Rows with 0 in Percent_SG:
#                        Team  Year  Percent_SG
# 263        Dallas Mavericks  2016         0.0
# 494       San Antonio Spurs  2005         0.0
# 495         Detroit Pistons  2005         0.0
# 496              Miami Heat  2005         0.0
# 498         Houston Rockets  2005         0.0
# 499  Minnesota Timberwolves  2005         0.0
# 502          Indiana Pacers  2005         0.0
# 503          Boston Celtics  2005         0.0
# 506           Chicago Bulls  2005         0.0
# 507      Washington Wizards  2005         0.0
# 509   Golden State Warriors  2005         0.0
# 515         Milwaukee Bucks  2005         0.0
# 517               Utah Jazz  2005         0.0
#
# Rows with 0 in Percent_PF:
#                        Team  Year  Percent_PF
# 107  Portland Trail Blazers  2022         0.0
# 195     Cleveland Cavaliers  2018         0.0
# 494       San Antonio Spurs  2005         0.0
# 495         Detroit Pistons  2005         0.0
# 504     Cleveland Cavaliers  2005         0.0
# 508    Los Angeles Clippers  2005         0.0
# 510         Toronto Raptors  2005         0.0
# 511      Los Angeles Lakers  2005         0.0
# 513           Orlando Magic  2005         0.0

# %%
position_cols = [col for col in full_df.columns if col.startswith('Percent')]
avg_p = full_df[position_cols].mean().sort_values()


plt.figure(figsize=(10,5))
plt.bar(avg_p.index, avg_p.values)
plt.title("Average Salary Percentage by Position")
plt.ylabel("Percentage of Team Salary")
plt.show()

# %%
champions = full_df[full_df['Championship'] == 1]
position_cols = [col for col in champions.columns if col.startswith('Percent')]
avg_pos = champions[position_cols].mean().sort_values()


plt.figure(figsize=(10,5))
plt.bar(avg_pos.index, avg_pos.values)
plt.title("Average Salary Percentage by Position (Championship Teams)")
plt.ylabel("Percentage of Team Salary")
plt.show()

# %%
avg_by_year = full_df.groupby("Year")[position_cols].mean().reset_index()
plt.figure(figsize=(12,6))

for col in position_cols:
    plt.plot(avg_by_year["Year"], avg_by_year[col], marker='o', label=col)
plt.title("Average Salary Percentage by Position Across Years")
plt.xlabel("Year")
plt.ylabel("Average % of Team Salary")
plt.legend(title="Position")
plt.grid(True)
plt.show()
